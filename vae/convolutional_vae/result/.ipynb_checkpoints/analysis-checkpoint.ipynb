# %%
import numpy as np
import random
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
train_loss = []
with open('meta_train_val_1000/train_loss.txt','r') as f:
    for line in f:
        train_loss.append(float(line.rstrip('\n')))
train_accuracy = []
with open('meta_train_val_1000/train_accuracy.txt','r') as f:
    for line in f:
        train_accuracy.append(float(line.rstrip('\n')))

# %%
val_loss = []
with open('meta_train_val_1000/val_loss.txt','r') as f:
    for line in f:
        val_loss.append(float(line.rstrip('\n')))
val_accuracy = []
with open('meta_train_val_1000/val_accuracy.txt','r') as f:
    for line in f:
        val_accuracy.append(float(line.rstrip('\n')))

# %%
print(len(val_accuracy),len(val_loss))
# Out:
# 100 100

# %%
x = np.arange(0, 100*len(train_accuracy), 100)
#s = train_accuracy
t = train_loss
plt.figure(figsize=(25,10))

#plt.plot(x,t,'b')
plt.plot(x, s,'r')
