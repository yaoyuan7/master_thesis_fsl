# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import t

_5w_1s_single_mean, _5w_1s_single_err = 0.4262, 0.0128
_5w_1s_multi_mean, _5w_1s_multi_err = 0.3921, 0.0089
_10w_1s_single_mean, _10w_1s_single_err = 0.3996, 0.0121
_10w_1s_multi_mean, _10w_1s_multi_err = 0.3605, 0.0097
_15w_1s_single_mean, _15w_1s_single_err = 0.3599, 0.0126
_15w_1s_multi_mean, _15w_1s_multi_err = 0.3361, 0.0139
_20w_1s_single_mean, _20w_1s_single_err = 0.3316, 0.0141
_20w_1s_multi_mean, _20w_1s_multi_err = 0.3275, 0.0168


_5w_5s_single_mean, _5w_5s_single_err = 0.6406, 0.0110
_5w_5s_multi_mean, _5w_5s_multi_err = 0.6221, 0.0050
_10w_5s_single_mean, _10w_5s_single_err = 0.6338, 0.0094
_10w_5s_multi_mean, _10w_5s_multi_err = 0.6329, 0.0057
_15w_5s_single_mean, _15w_5s_single_err = 0.6203, 0.0066
_15w_5s_multi_mean, _15w_5s_multi_err = 0.6227, 0.0103
_20w_5s_single_mean, _20w_5s_single_err = 0.6231, 0.0073
_20w_5s_multi_mean, _20w_5s_multi_err = 0.6109, 0.0100


_1shot_single_mean = [_5w_1s_single_mean,_10w_1s_single_mean,_15w_1s_single_mean,_20w_1s_single_mean]
_5shot_single_mean = [_5w_5s_single_mean,_10w_5s_single_mean,_15w_5s_single_mean,_20w_5s_single_mean]
_1shot_multi_mean = [_5w_1s_multi_mean,_10w_1s_multi_mean,_15w_1s_multi_mean,_20w_1s_multi_mean]
_5shot_multi_mean = [_5w_5s_multi_mean,_10w_5s_multi_mean,_15w_5s_multi_mean,_20w_5s_multi_mean]

_1shot_single_err = [_5w_1s_single_err,_10w_1s_single_err,_15w_1s_single_err,_20w_1s_single_err]
_5shot_single_err = [_5w_5s_single_err,_10w_5s_single_err,_15w_5s_single_err,_20w_5s_single_err]
_1shot_multi_err = [_5w_1s_multi_err,_10w_1s_multi_err,_15w_1s_multi_err,_20w_1s_multi_err]
_5shot_multi_err = [_5w_5s_multi_err,_10w_5s_multi_err,_15w_5s_multi_err,_20w_5s_multi_err]


model = ['a','b','c','d']
x_pos = np.arange(4)
width = 0.35

fig, ax = plt.subplots()
rects1 = ax.bar(x_pos-0.175, _5shot_single_mean, width,yerr=_5shot_single_err, 
                align='center', alpha=0.5, ecolor='black', capsize=10,label='5shot with single fake image')
rects2 = ax.bar(x_pos+0.175, _5shot_multi_mean, width,yerr=_5shot_multi_err, 
                align='center', alpha=0.5, ecolor='black', capsize=10,label='5shot with multi fake images')

ax.set_ylabel('Accuracy')
ax.set_xticks(x_pos)
ax.set_ylim([0.45,0.75])
ax.set_xticklabels(model)
ax.set_title('Testing accuracy with 95% confident intervals')
ax.yaxis.grid(True)
ax.legend()

def autolabel(rects, xpos='center'):
    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.1, 'right': 0, 'left': 1}  # x_txt = x + w*off

    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()*offset[xpos], 1.05*height,
                '{}'.format(height), ha=ha[xpos], va='bottom')

# Save the figure and show
plt.tight_layout()
autolabel(rects1, "left")
autolabel(rects2, "right")
#plt.savefig('5shot.png')
plt.show()
