# %%
import numpy as np
from matplotlib import pyplot as plt
from scipy.stats import t
import seaborn as sns

# %%
_001_20w_5s_1600_mean,_01_20w_5s_1600_mean,_1_20w_5s_1600_mean = 0.5642,0.5593,0.5830 
_001_20w_5s_1024_mean,_01_20w_5s_1024_mean,_1_20w_5s_1024_mean = 0.5663,0.5682,0.5885
_001_20w_5s_512_mean,_01_20w_5s_512_mean,_1_20w_5s_512_mean = 0.5615,0.5657,0.5827
_001_20w_5s_128_mean,_01_20w_5s_128_mean,_1_20w_5s_128_mean = 0.5748,0.5785,0.5837
pn_20w_5s_mean = 0.682
_001_15w_5s_1600_mean,_01_15w_5s_1600_mean,_1_15w_5s_1600_mean = 0.5646,0.5716,0.5800
_001_15w_5s_1024_mean,_01_15w_5s_1024_mean,_1_15w_5s_1024_mean = 0.5593,0.5752,0.5792
_001_15w_5s_512_mean,_01_15w_5s_512_mean,_1_15w_5s_512_mean = 0.5746,0.5795,0.5943
_001_15w_5s_128_mean,_01_15w_5s_128_mean,_1_15w_5s_128_mean = 0.5834,0.5780,0.5884
pn_15w_5s_mean = 0.6803

_001_10w_5s_1600_mean,_01_10w_5s_1600_mean,_1_10w_5s_1600_mean = 0.5679,0.5743,0.5959
_001_10w_5s_1024_mean,_01_10w_5s_1024_mean,_1_10w_5s_1024_mean = 0.5817,0.5736,0.5850
_001_10w_5s_512_mean,_01_10w_5s_512_mean,_1_10w_5s_512_mean = 0.5802,0.5773,0.5773
_001_10w_5s_128_mean,_01_10w_5s_128_mean,_1_10w_5s_128_mean = 0.5874,0.5838,0.5878
pn_10w_5s_mean = 0.6749

_001_5w_5s_1600_mean,_01_5w_5s_1600_mean,_1_5w_5s_1600_mean = 0.5887,0.5878,0.5825
_001_5w_5s_1024_mean,_01_5w_5s_1024_mean,_1_5w_5s_1024_mean = 0.5935,0.5792,0.5875
_001_5w_5s_512_mean,_01_5w_5s_512_mean,_1_5w_5s_512_mean = 0.5874,0.5967,0.5947
_001_5w_5s_128_mean,_01_5w_5s_128_mean,_1_5w_5s_128_mean = 0.5885,0.5964,0.5908
pn_5w_5s_mean = 0.6577

# %%
_001_20w_5s_1600_va,_01_20w_5s_1600_va,_1_20w_5s_1600_va = 0.0088,0.0087,0.0086
_001_20w_5s_1024_va,_01_20w_5s_1024_va,_1_20w_5s_1024_va = 0.0084,0.0082,0.0088
_001_20w_5s_512_va,_01_20w_5s_512_va,_1_20w_5s_512_va = 0.0085,0.0084,0.0083
_001_20w_5s_128_va,_01_20w_5s_128_va,_1_20w_5s_128_va = 0.0090,0.0087,0.0082
pn_20w_5s_va = 0.0066

_001_15w_5s_1600_va,_01_15w_5s_1600_va,_1_15w_5s_1600_va = 0.0081,0.0081,0.0093
_001_15w_5s_1024_va,_01_15w_5s_1024_va,_1_15w_5s_1024_va = 0.0082,0.0088,0.0083
_001_15w_5s_512_va,_01_15w_5s_512_va,_1_15w_5s_512_va = 0.0091,0.0083,0.0094
_001_15w_5s_128_va,_01_15w_5s_128_va,_1_15w_5s_128_va = 0.0084,0.0087,0.0088
pn_15w_5s_va = 0.0066

_001_10w_5s_1600_va,_01_10w_5s_1600_va,_1_10w_5s_1600_va = 0.0086,0.0080,0.0086
_001_10w_5s_1024_va,_01_10w_5s_1024_va,_1_10w_5s_1024_va = 0.0087,0.0083,0.0088
_001_10w_5s_512_va,_01_10w_5s_512_va,_1_10w_5s_512_va = 0.0084,0.0087,0.0087
_001_10w_5s_128_va,_01_10w_5s_128_va,_1_10w_5s_128_va = 0.0084,0.0087,0.0092
pn_10w_5s_va = 0.0070

_001_5w_5s_1600_va,_01_5w_5s_1600_va,_1_5w_5s_1600_va = 0.0091,0.0087,0.0087
_001_5w_5s_1024_va,_01_5w_5s_1024_va,_1_5w_5s_1024_va = 0.0086,0.0088,0.0090
_001_5w_5s_512_va,_01_5w_5s_512_va,_1_5w_5s_512_va = 0.0084,0.0086,0.0085
_001_5w_5s_128_va,_01_5w_5s_128_va,_1_5w_5s_128_va = 0.0089,0.0090,0.0084
pn_5w_5s_va = 0.0070

# %%
_1_128_mean = [_1_5w_5s_128_mean,_1_10w_5s_128_mean,_1_15w_5s_128_mean,_1_20w_5s_128_mean]
_1_128_va = [_1_5w_5s_128_va,_1_10w_5s_128_va,_1_15w_5s_128_va,_1_20w_5s_128_va]

_01_128_mean = [_01_5w_5s_128_mean,_01_10w_5s_128_mean,_01_15w_5s_128_mean,_01_20w_5s_128_mean]
_01_128_va = [_01_5w_5s_128_va,_01_10w_5s_128_va,_01_15w_5s_128_va,_01_20w_5s_128_va]

_001_128_mean = [_001_5w_5s_128_mean,_001_10w_5s_128_mean,_001_15w_5s_128_mean,_001_20w_5s_128_mean]
_001_128_va = [_001_5w_5s_128_va,_001_10w_5s_128_va,_001_15w_5s_128_va,_001_20w_5s_128_va]

_1_512_mean = [_1_5w_5s_512_mean,_1_10w_5s_512_mean,_1_15w_5s_512_mean,_1_20w_5s_512_mean]
_1_512_va = [_1_5w_5s_512_va,_1_10w_5s_512_va,_1_15w_5s_512_va,_1_20w_5s_512_va]

_01_512_mean = [_01_5w_5s_512_mean,_01_10w_5s_512_mean,_01_15w_5s_512_mean,_01_20w_5s_512_mean]
_01_512_va = [_01_5w_5s_512_va,_01_10w_5s_512_va,_01_15w_5s_512_va,_01_20w_5s_512_va]

_001_512_mean = [_001_5w_5s_512_mean,_001_10w_5s_512_mean,_001_15w_5s_512_mean,_001_20w_5s_512_mean]
_001_512_va = [_001_5w_5s_512_va,_001_10w_5s_512_va,_001_15w_5s_512_va,_001_20w_5s_512_va]

_1_1024_mean = [_1_5w_5s_1024_mean,_1_10w_5s_1024_mean,_1_15w_5s_1024_mean,_1_20w_5s_1024_mean]
_1_1024_va = [_1_5w_5s_1024_va,_1_10w_5s_1024_va,_1_15w_5s_1024_va,_1_20w_5s_1024_va]

_01_1024_mean = [_01_5w_5s_1024_mean,_01_10w_5s_1024_mean,_01_15w_5s_1024_mean,_01_20w_5s_1024_mean]
_01_1024_va = [_01_5w_5s_1024_va,_01_10w_5s_1024_va,_01_15w_5s_1024_va,_01_20w_5s_1024_va]

_001_1024_mean = [_001_5w_5s_1024_mean,_001_10w_5s_1024_mean,_001_15w_5s_1024_mean,_001_20w_5s_1024_mean]
_001_1024_va = [_001_5w_5s_1024_va,_001_10w_5s_1024_va,_001_15w_5s_1024_va,_001_20w_5s_1024_va]

_1_1600_mean = [_1_5w_5s_1600_mean,_1_10w_5s_1600_mean,_1_15w_5s_1600_mean,_1_20w_5s_1600_mean]
_1_1600_va = [_1_5w_5s_1600_va,_1_10w_5s_1600_va,_1_15w_5s_1600_va,_1_20w_5s_1600_va]

_01_1600_mean = [_01_5w_5s_1600_mean,_01_10w_5s_1600_mean,_01_15w_5s_1600_mean,_01_20w_5s_1600_mean]
_01_1600_va = [_01_5w_5s_1600_va,_01_10w_5s_1600_va,_01_15w_5s_1600_va,_01_20w_5s_1600_va]

_001_1600_mean = [_001_5w_5s_1600_mean,_001_10w_5s_1600_mean,_001_15w_5s_1600_mean,_001_20w_5s_1600_mean]
_001_1600_va = [_001_5w_5s_1600_va,_001_10w_5s_1600_va,_001_15w_5s_1600_va,_001_20w_5s_1600_va]

pn_mean = [pn_5w_5s_mean, pn_10w_5s_mean,pn_15w_5s_mean,pn_20w_5s_mean]
pn_va = [pn_5w_5s_va,pn_10w_5s_va,pn_15w_5s_va,pn_20w_5s_va]

# %%
model = ['training 5-way','training 10-way','training 15-way','training 20-way']
x_pos = np.arange(0,4*9,9)
width = 1

sns.set(style="whitegrid")
fig = plt.figure(figsize=(15,8))
flatui = ["#b1c0d4","#d4e5ea","#ffe7e7","#feffa8","#c4ffc1","#ffa5a5","#000000"]
ax=plt.subplot(1, 1, 1)
ax.set_color_cycle(sns.color_palette(flatui))
rects1 = ax.bar(x_pos-3, _1_1024_mean, width,yerr=_1_128_va, 
                align='center', alpha=1, ecolor='black', capsize=6,label=r'$\alpha$=0.1 dimension=1024')
rects2 = ax.bar(x_pos-2, _01_1024_mean, width,yerr=_01_128_va, 
                align='center', alpha=1, ecolor='black', capsize=6,label=r'$\alpha$=0.01 dimension=1024')
rects3 = ax.bar(x_pos-1, _001_1024_mean, width,yerr=_001_128_va, 
                align='center', alpha=1, ecolor='black', capsize=6,label=r'$\alpha$=0.001 dimension=1024')
rects4 = ax.bar(x_pos+0, _1_1600_mean, width,yerr=_1_128_va, 
                align='center', alpha=1, ecolor='black', capsize=6,label=r'$\alpha$=0.1 dimension=1600')
rects5 = ax.bar(x_pos+1, _01_1600_mean, width,yerr=_01_128_va, 
                align='center', alpha=1, ecolor='black', capsize=6,label=r'$\alpha$=0.01 dimension=1600')
rects6 = ax.bar(x_pos+2, _001_1600_mean, width,yerr=_001_128_va, 
                align='center', alpha=1, ecolor='black', capsize=6,label=r'$\alpha$=0.001 dimension=1600')
rects7 = ax.bar(x_pos+3, pn_mean, width,yerr=pn_va, 
                align='center', alpha=0.7, ecolor='black', capsize=6,label='prototypical network results')

ax.set_ylabel('Accuracy', fontsize=12)
ax.set_xticks(x_pos)
ax.set_ylim([0.45,0.8])
ax.set_xticklabels(model, fontsize=12)
#ax.set_title('Testing accuracy with 95% confident intervals')
ax.yaxis.grid(True)
ax.legend(fontsize=18,prop={'size': 12})

def autolabel(rects, xpos='center'):
    xpos = xpos.lower()  # normalize the case of the parameter
    ha = {'center': 'center', 'right': 'left', 'left': 'right'}
    offset = {'center': 0.1, 'right': 0, 'left': 1}  # x_txt = x + w*off

    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()*offset[xpos], 1.05*height,
                '{}'.format(height), ha=ha[xpos], va='bottom')

# Save the figure and show
plt.tight_layout()
#autolabel(rects1, "left")
#autolabel(rects2, "center")
#autolabel(rects3, "right")
fig.savefig('error2.jpg',bbox_inches='tight')
plt.show()
# Out:
# /Users/yaoyuan/anaconda3/lib/python3.6/site-packages/matplotlib/cbook.py:136: MatplotlibDeprecationWarning: The set_color_cycle attribute was deprecated in version 1.5. Use set_prop_cycle instead.
#   warnings.warn(message, mplDeprecation, stacklevel=1)
